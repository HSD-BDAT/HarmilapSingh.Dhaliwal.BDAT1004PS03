# %% [markdown]
# # Problem Set 3
#
# This problem set is based on lectures 9 and 10. For a complete list of topics please consult page 2 of the course syllabus. Please consult the "Instructions for Problem Set Submissions" document under course information before submitting your assignment.

# %% [markdown]
# ### For this assignment: Pandas, Numpy, and Matplotlib library documentation is used extensively for reference.

# %% [markdown]
# ---
# ---
#
# ## Question 1 (Occupations)
#
# Introduction:
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.

# %% [markdown]
# #### Step 1. Import the necessary libraries
# #### Step 2. Import the dataset from this address. https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user
# #### Step 3. Assign it to a variable called users.
# #### Step 4. Discover what is the mean age per occupation

# %%
# Step 1. Import the necessary libraries  
import pandas as pd

# Step 2. Import the dataset from this address. https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user   
# Step 3. Assign it to a variable called users.  
users = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', sep = "|")

# Step 4. Discover what is the mean age per occupation  
print("Mean ager per occupation:")
# group by Ocuupation, take a mean of Age and round the result to 2 digits
print(users.groupby('occupation')['age'].mean().round(2))
# Out:
# Mean ager per occupation:
# occupation
# administrator    38.75
# artist           31.39
# doctor           43.57
# educator         42.01
# engineer         36.39
# entertainment    29.22
# executive        38.72
# healthcare       41.56
# homemaker        32.57
# lawyer           36.75
# librarian        40.00
# marketing        37.62
# none             26.56
# other            34.52
# programmer       33.12
# retired          63.07
# salesman         35.67
# scientist        35.55
# student          22.08
# technician       33.15
# writer           36.31
# Name: age, dtype: float64

# %% [markdown]
# ---
# #### Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
print("Male ratio per occupation")
# group by Occupation and Gender
# Calculate counts of gender
# Unstack, convert single column to multiple based on Gender;    ?pd.DataFrame.unstack
# Replace Na with 0
# Calculate % and sort by descending Male Ratio
print(users.groupby(['occupation', 'gender'])['gender'].count().unstack().fillna(0).
      apply(lambda x:round((x*100)/sum(x), 2), 1).sort_values('M', ascending = False)['M'])
# Out:
# Male ratio per occupation
# occupation
# doctor           100.00
# engineer          97.01
# technician        96.30
# retired           92.86
# programmer        90.91
# executive         90.62
# scientist         90.32
# entertainment     88.89
# lawyer            83.33
# salesman          75.00
# educator          72.63
# student           69.39
# other             65.71
# marketing         61.54
# writer            57.78
# none              55.56
# administrator     54.43
# artist            53.57
# librarian         43.14
# healthcare        31.25
# homemaker         14.29
# Name: M, dtype: float64

# %% [markdown]
# ---
# #### Step 6. For each occupation, calculate the minimum and maximum ages

# %%
print("Min. and Max. age each occupation")
# grouo by Age and use `agg` to calculate Max and Min
print(users.groupby('occupation')['age'].agg(['max', 'min']))
# Out:
# Min. and Max. age each occupation
#                max  min
# occupation
# administrator   70   21
# artist          48   19
# doctor          64   28
# educator        63   23
# engineer        70   22
# entertainment   50   15
# executive       69   22
# healthcare      62   22
# homemaker       50   20
# lawyer          53   21
# librarian       69   23
# marketing       55   24
# none            55   11
# other           64   13
# programmer      63   20
# retired         73   51
# salesman        66   18
# scientist       55   23
# student         42    7
# technician      55   21
# writer          60   18

# %% [markdown]
# ---
# #### Step 7. For each combination of occupation and sex, calculate the mean age

# %%
print("Mean age for occupation and sex")
# group by occupation and sex, calculate Mean of age, round the values to 2 and unstack
print(users.groupby(['occupation', 'gender'])['age'].mean().round(2).unstack())
# Out:
# Mean age for occupation and sex
# gender             F      M
# occupation
# administrator  40.64  37.16
# artist         30.31  32.33
# doctor           NaN  43.57
# educator       39.12  43.10
# engineer       29.50  36.60
# entertainment  31.00  29.00
# executive      44.00  38.17
# healthcare     39.82  45.40
# homemaker      34.17  23.00
# lawyer         39.50  36.20
# librarian      40.00  40.00
# marketing      37.20  37.88
# none           36.50  18.60
# other          35.47  34.03
# programmer     32.17  33.22
# retired        70.00  62.54
# salesman       27.00  38.56
# scientist      28.33  36.32
# student        20.75  22.67
# technician     38.00  32.96
# writer         37.63  35.35

# %% [markdown]
# ---
# #### Step 8. For each occupation present the percentage of women and men

# %%
print("\nGender ratio occupation wise")
# Same as step 5
# Don't sort
# Show women ratio as well
print(users.groupby(['occupation', 'gender'])['gender'].count().unstack().fillna(0).
      apply(lambda x:round((x*100)/sum(x), 2), 1))
# Out:
# Gender ratio occupation wise
# gender             F       M
# occupation
# administrator  45.57   54.43
# artist         46.43   53.57
# doctor          0.00  100.00
# educator       27.37   72.63
# engineer        2.99   97.01
# entertainment  11.11   88.89
# executive       9.38   90.62
# healthcare     68.75   31.25
# homemaker      85.71   14.29
# lawyer         16.67   83.33
# librarian      56.86   43.14
# marketing      38.46   61.54
# none           44.44   55.56
# other          34.29   65.71
# programmer      9.09   90.91
# retired         7.14   92.86
# salesman       25.00   75.00
# scientist       9.68   90.32
# student        30.61   69.39
# technician      3.70   96.30
# writer         42.22   57.78

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Question 2 (Euro Teams)

# %% [markdown]
# #### Step 1. Import the necessary libraries
# #### Step 2. Import the dataset from this address https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv
# #### Step 3. Assign it to a variable called euro12

# %%
# Step 1. Import the necessary libraries 
import pandas as pd
import numpy as np

# Step 2. Import the dataset from this address https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv  
# Step 3. Assign it to a variable called euro12 
euro12 = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv')

# %% [markdown]
# ---
# #### Step 4. Select only the Goal column

# %%
print("Goals Column")
print(euro12.Goals)
# Out:
# Goals Column
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# ---
# #### Step 5. How many team participated in the Euro2012?

# %%
# unique()
print("{} teams participated in the Euro 2012.".format(len(euro12.Team.unique())))
# Out:
# 16 teams participated in the Euro 2012.

# %% [markdown]
# ---
# #### Step 6. What is the number of columns in the dataset?

# %%
print("There are {} columns in the dataset.".format(len(euro12.columns)))
# Out:
# There are 35 columns in the dataset.

# %% [markdown]
# ---
# #### Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %%
discipline = euro12[['Team', 'Yellow Cards', 'Red Cards']]
discipline.head()
# Out:
#              Team  Yellow Cards  Red Cards
# 0         Croatia             9          0
# 1  Czech Republic             7          0
# 2         Denmark             4          0
# 3         England             5          0
# 4          France             6          0

# %% [markdown]
# ---
# #### Step 8. Sort the teams by Red Cards, then to Yellow Cards

# %%
# ?pd.DataFrame.sort_values
discipline.sort_values(['Red Cards', 'Yellow Cards'], ascending = False)
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %% [markdown]
# ---
# #### Step 9. Calculate the mean Yellow Cards given per Team

# %%
print("Mean of Yellow Cards per Team: {}".format(discipline['Yellow Cards'].mean()))
# Out:
# Mean of Yellow Cards per Team: 7.4375

# %% [markdown]
# ---
# #### Step 10. Filter teams that scored more than 6 goals

# %%
print("Teams that scored more than 6 goals")
euro12[['Team','Goals']][euro12.Goals > 6]
# Out:
# Teams that scored more than 6 goals
#        Team  Goals
# 5   Germany     10
# 13    Spain     12

# %% [markdown]
# ---
# #### Step 11. Select the teams that start with G

# %%
print("Teams whose name starts with 'G'")
# ?str.startswith
euro12.Team[euro12.Team.str.startswith('G')]
# Out:
# Teams whose name starts with 'G'
# 5    Germany
# 6     Greece
# Name: Team, dtype: object

# %% [markdown]
# ---
# #### Step 12. Select the first 7 columns

# %%
euro12.iloc[:,:7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ---
# #### Step 13. Select all columns except the last 3

# %%
euro12.iloc[:,:-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ---
# #### Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
euro12.loc[euro12.Team.isin(['England', 'Italy', 'Russia']), ['Team', 'Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Question 3 (Housing)

# %% [markdown]
# #### Step 1. Import the necessary libraries
# #### Step 2. Create 3 different Series, each of length 100, as follows:
# - The first a random number from 1 to 4
# - The second a random number from 1 to 3
# - The third a random number from 10,000 to 30,000

# %%
# Step 1. Import the necessary libraries  
import numpy as np
import pandas as pd

# Step 2. Create 3 different Series, each of length 100, as follows:
# The first a random number from 1 to 4
# The second a random number from 1 to 3
# The third a random number from 10,000 to 30,000
# ?np.random.choice
bedrs = pd.Series(np.random.choice(range(1, 4), 100))
baths = pd.Series(np.random.choice(range(1, 3), 100))
price_sqr_meter = pd.Series(np.random.choice(range(10000, 30000), 100))

# %% [markdown]
# ---
# #### Step 3. Create a DataFrame by joinning the Series by column
# #### Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter

# %%
# >pd.concat
# combine 3 series by column and make a n*3 DataFrame
housing_df = pd.concat([bedrs, baths, price_sqr_meter], axis = 1)
housing_df.columns = ['bedrs', 'baths', 'price_sqr_meter']
housing_df.head()
# Out:
#    bedrs  baths  price_sqr_meter
# 0      2      1            17801
# 1      1      1            24102
# 2      3      1            17611
# 3      1      1            22829
# 4      1      1            16277

# %% [markdown]
# ---
# #### Step 5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'
# #### Step 6. Ops it seems it is going only until index 99. Is it true?
# #### Step 7. Reindex the DataFrame so it goes from 0 to 299

# %%
# stack opposite of unstack
# ?pd.DataFrame.stack
bigColumn = pd.DataFrame(housing_df.stack())
print(bigColumn.index)
bigColumn.reset_index(inplace = True, drop = True)
print("\nAfter Correction:")
print(bigColumn.index)
# Out:
# MultiIndex([( 0,           'bedrs'),
#             ( 0,           'baths'),
#             ( 0, 'price_sqr_meter'),
#             ( 1,           'bedrs'),
#             ( 1,           'baths'),
#             ( 1, 'price_sqr_meter'),
#             ( 2,           'bedrs'),
#             ( 2,           'baths'),
#             ( 2, 'price_sqr_meter'),
#             ( 3,           'bedrs'),
#             ...
#             (96, 'price_sqr_meter'),
#             (97,           'bedrs'),
#             (97,           'baths'),
#             (97, 'price_sqr_meter'),
#             (98,           'bedrs'),
#             (98,           'baths'),
#             (98, 'price_sqr_meter'),
#             (99,           'bedrs'),
#             (99,           'baths'),
#             (99, 'price_sqr_meter')],
#            length=300)
#
# After Correction:
# RangeIndex(start=0, stop=300, step=1)

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Question 4 (Wind Statistics)
#
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise easier, in particular for the bonus question.
# You should be able to perform all of these operations without using a for loop or other looping construct.
#
# The data in 'wind.data' has the following format:
#
# The first three columns are year, month, and day. The remaining 12 columns are average windspeeds in knots at 12 locations in Ireland on that day.

# %% [markdown]
# #### Step 1. Import the necessary libraries
# #### Step 2. Import the dataset from this address (https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data)
# #### Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

# %%
# Step 1. Import the necessary libraries  
import pandas as pd
import datetime
import numpy as np

# Step 2. Import the dataset from this address 
# (https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data) 
# Step 3 name
data = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data', sep = '\s+')
print(data.head())

# # Step 3. Replace the first 3 columns by a proper datetime index.  
# ?pd.to_numeric
# First step, join the 'yr', 'mo', 'dy' by conveting them to integers first
# Convert string to DateTime by ?pd.to_datetime
data['Date'] = data[['Yr','Mo','Dy']].apply(lambda x: '-'.join(pd.to_numeric(x, downcast = 'integer').values.astype(str)), axis="columns")
data.Date = pd.to_datetime(data.Date)
data.Date.head()
# Out:
#    Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  61   1   1  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  61   1   2  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  61   1   3  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3  61   1   4  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4  61   1   5  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83
# 0   2061-01-01
# 1   2061-01-02
# 2   2061-01-03
# 3   2061-01-04
# 4   2061-01-05
# Name: Date, dtype: datetime64[ns]

# %% [markdown]
# ---
# #### Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

# %%
def changeDate(x):
    # for dates with years greater than or equal to 2061
    if x.year >= 2061:
        # ?pd.offsets.DateOffset
        # subtract 100 years
        x = x - pd.offsets.DateOffset(years = 100)
    return(x)

# apply function to each element of Date column
data.Date = data.Date.apply(changeDate)
data.Date
# Out:
# 0      1961-01-01
# 1      1961-01-02
# 2      1961-01-03
# 3      1961-01-04
# 4      1961-01-05
#           ...
# 6569   1978-12-27
# 6570   1978-12-28
# 6571   1978-12-29
# 6572   1978-12-30
# 6573   1978-12-31
# Name: Date, Length: 6574, dtype: datetime64[ns]

# %% [markdown]
# ---
# #### Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data.index = data.Date
data.drop(['Yr', 'Mo', 'Dy', 'Date'], axis = 1, inplace = True)
data.index
# Out:
# DatetimeIndex(['1961-01-01', '1961-01-02', '1961-01-03', '1961-01-04',
#                '1961-01-05', '1961-01-06', '1961-01-07', '1961-01-08',
#                '1961-01-09', '1961-01-10',
#                ...
#                '1978-12-22', '1978-12-23', '1978-12-24', '1978-12-25',
#                '1978-12-26', '1978-12-27', '1978-12-28', '1978-12-29',
#                '1978-12-30', '1978-12-31'],
#               dtype='datetime64[ns]', name='Date', length=6574, freq=None)

# %% [markdown]
# ---
# #### Step 6. Compute how many values are missing for each location over the entire record. They should be ignored in all calculations below.

# %% [markdown]
# ### Pandas automatically ignores NAs, by default `skipna` is set to `True`

# %%
print("Missing Values for each location")
data.isna().sum()
# Out:
# Missing Values for each location
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %% [markdown]
# ---
# #### Step 7. Compute how many non-missing values there are in total.

# %%
print("Non-Missing observations for each column")
data.shape[0] - data.isna().sum()
# Out:
# Non-Missing observations for each column
# RPT    6568
# VAL    6571
# ROS    6572
# KIL    6569
# SHA    6572
# BIR    6574
# DUB    6571
# CLA    6572
# MUL    6571
# CLO    6573
# BEL    6574
# MAL    6570
# dtype: int64

# %% [markdown]
# ---
# #### Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.

# %%
# First mean, calculates means by columns and then 2nd mean, takes mean of 1 column to get the result
print("Mean Windspeed over all the locations and all the times is: {}".format(round((data.mean()).mean(), 2)))
# Out:
# Mean Windspeed over all the locations and all the times is: 10.23

# %% [markdown]
# ---
# #### Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days

# %%
# use agg to apply all the functions at the same time
loc_stats = data.agg(['min', 'max', 'mean', 'std']).round(2)
loc_stats
# Out:
#         RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL    CLO  \
# min    0.67   0.21   1.50   0.00   0.13   0.00   0.00   0.00   0.00   0.04
# max   35.80  33.37  33.84  28.46  37.54  26.16  30.37  31.08  25.88  28.21
# mean  12.36  10.64  11.66   6.31  10.46   7.09   9.80   8.50   8.49   8.71
# std    5.62   5.27   5.01   3.61   4.94   3.97   4.98   4.50   4.17   4.50
#
#         BEL    MAL
# min    0.13   0.67
# max   42.38  42.54
# mean  13.12  15.60
# std    5.84   6.70

# %% [markdown]
# ---
# #### Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.

# %%
# use `day_name' to group by Day Nme
# this will calculate all the functions for each column
day_stats = data.groupby(data.index.day_name()).agg(['mean', 'min', 'max', 'std'])

#############################################################################################
# for the next function I got the logic from StackOverflow
# https://stackoverflow.com/questions/37835508/how-to-do-multi-column-from-tuples
# using this so that we can group by our Variable
day_stats.columns = pd.MultiIndex.from_tuples(day_stats.columns, names=["first", "second"])

# level 1 groups by the first element of the tuple which is our variable
day_stats = round(day_stats.groupby(level = 1, axis = 1).mean(), 2)
#############################################################################################

# Reorder 
day_stats = day_stats.loc[['Monday', 'Tuesday','Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'], 
                          ['min', 'mean', 'max', 'std']]
day_stats
# Out:
# second      min   mean    max   std
# Date
# Monday     0.80  10.24  28.74  4.99
# Tuesday    0.64  10.20  27.72  4.92
# Wednesday  0.58  10.23  29.96  4.97
# Thursday   0.64  10.21  31.99  4.97
# Friday     0.68  10.13  29.18  4.80
# Saturday   0.72  10.27  30.00  4.83
# Sunday     0.68  10.31  31.42  4.99

# %% [markdown]
# ---
# #### Step 11. Find the average windspeed in January for each location. (Treat January 1961 and January 1962 both as January)

# %%
print(data.index[0:5])
print(data.index[0:5].month_name())
# Out:
# DatetimeIndex(['1961-01-01', '1961-01-02', '1961-01-03', '1961-01-04',
#                '1961-01-05'],
#               dtype='datetime64[ns]', name='Date', freq=None)
# Index(['January', 'January', 'January', 'January', 'January'], dtype='object', name='Date')

# %%
### Data is already considering January correctly

# %%
# group by month name and subset only the January column
a = data.groupby(data.index.month_name()).apply(lambda x: x.mean().round(2))
a.loc['January']
# Out:
# RPT    14.85
# VAL    12.91
# ROS    13.30
# KIL     7.20
# SHA    11.67
# BIR     8.05
# DUB    11.82
# CLA     9.51
# MUL     9.54
# CLO    10.05
# BEL    14.55
# MAL    18.03
# Name: January, dtype: float64

# %% [markdown]
# ---
# #### Step 12. Downsample the record to a yearly frequency for each location.

# %%
# ?pd.resample
# Downsample to Years and average the rows
data.resample('Y').mean().round(2)
# Out:
#               RPT    VAL    ROS   KIL    SHA   BIR    DUB    CLA   MUL    CLO  \
# Date
# 1961-12-31  12.30  10.35  11.36  6.96  10.88  7.73   9.73   8.86  8.65   9.84
# 1962-12-31  12.25  10.11  11.73  6.96  10.66  7.39  11.02   8.79  8.32   9.68
# 1963-12-31  12.81  10.84  12.54  7.33  11.72  8.43  11.08  10.34  8.90  10.22
# 1964-12-31  12.36  10.92  12.10  6.79  11.45  7.57  10.26   9.47  7.79  10.21
# 1965-12-31  12.45  11.08  11.85  6.86  11.02  7.48  10.62   8.88  7.91   9.92
# 1966-12-31  13.46  11.56  12.02  7.35  11.81  7.79  10.58   8.84  8.51   9.77
# 1967-12-31  12.74  10.99  11.74  7.14  11.63  7.37  10.65   9.33  8.65   9.55
# 1968-12-31  11.84  10.47  11.41  6.48  10.76  6.07   8.86   8.26  7.22   7.83
# 1969-12-31  11.17   9.72  10.90  5.77   9.87  6.19   8.56   7.71  7.92   7.75
# 1970-12-31  12.60  10.73  11.73  6.22  10.57  7.61   9.61   8.33  9.30   8.29
# 1971-12-31  11.27   9.10  11.09  5.24   9.44  6.10   8.39   6.76  7.92   7.23
# ...

# %% [markdown]
# ---
# #### Step 13. Downsample the record to a monthly frequency for each location.

# %%
# ?pd.resample
# Downsample to Months and average the rows
data.resample('M').mean().round(2)
# Out:
#               RPT    VAL    ROS   KIL    SHA    BIR    DUB    CLA    MUL  \
# Date
# 1961-01-31  14.84  11.99  13.43  7.74  11.07   8.59  11.18   9.25   9.09
# 1961-02-28  16.27  14.98  14.44  9.23  13.85  10.94  11.89  11.85  11.82
# 1961-03-31  10.89  11.30  10.75  7.28  10.51   8.87   9.64   9.83  10.29
# 1961-04-30  10.72   9.43  10.00  5.83   8.43   6.49   6.93   7.09   7.34
# 1961-05-31   9.86   8.85  10.82  5.91   9.49   6.57   7.60   8.18   8.04
# ...           ...    ...    ...   ...    ...    ...    ...    ...    ...
# 1978-08-31   9.65   8.26   9.03  4.50   7.37   5.94   5.65   5.42   7.24
# 1978-09-30  10.91  10.89  10.64  5.72  10.37   9.28  10.79   9.58  10.07
# 1978-10-31   9.90   8.67   9.30  4.72   8.53   6.77   8.12   7.34   8.30
# 1978-11-30  16.15  14.80  13.51  7.32  11.48   8.74  11.49   9.66  10.70
# 1978-12-31  16.18  13.75  15.64  7.09  11.40   9.24  12.08  10.19  10.62
#
#               CLO    BEL    MAL
# Date
# 1961-01-31  10.11  13.88  14.70
# ...

# %% [markdown]
# ---
# #### Step 14. Downsample the record to a weekly frequency for each location.

# %%
# ?pd.resample
# Downsample to Weeks and average the rows
data.resample('W').mean().round(2)
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# Date
# 1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83
# 1961-01-08  13.54  11.49  10.49   6.42   9.47   6.44  11.06   6.62   8.43
# 1961-01-15  12.47   8.97  11.96   4.63   7.35   5.07   7.54   6.82   5.71
# 1961-01-22  13.20   9.86  12.98   6.33   8.97   7.42   9.26   7.88   7.15
# 1961-01-29  19.88  16.14  18.23  12.72  17.43  14.83  15.53  15.16  14.48
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1978-12-03  14.93  11.23  13.94   5.57  10.22   8.62   9.64   7.69   9.01
# 1978-12-10  20.74  19.19  17.03   9.78  15.29  12.77  14.44  12.49  13.87
# 1978-12-17  16.76  14.69  14.99   6.92  11.40   7.27  10.21   7.97   9.17
# 1978-12-24  11.16   8.01  13.17   4.00   7.83   6.29   7.80   8.67   7.15
# 1978-12-31  14.95  11.80  16.04   6.51   9.66   8.62  13.71  10.48  10.87
#
#               CLO    BEL    MAL
# Date
# 1961-01-01  12.58  18.50  15.04
# ...

# %% [markdown]
# ---
# #### Step 15. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
# data starts from 1st January, so disregard the first element
new_df = data.iloc[1:]

# First downsample to weekly frequency, and then apply aggregate functions
weekly_stats = new_df.resample("W").mean()[:52].agg(['min', 'max', 'mean', 'std'], axis = 1).round(2)

# Python shows index of last day of the week, data is calculated from '1961-01-02', so updating index
weekly_stats.index = pd.date_range(start = '1961-01-02', periods = 52, freq = '7D')
weekly_stats
# Out:
#               min    max   mean   std
# 1961-01-02   6.42  13.54   9.85  2.60
# 1961-01-09   4.63  12.47   8.35  2.72
# 1961-01-16   6.33  13.20   9.37  2.22
# 1961-01-23  12.72  22.53  16.96  2.92
# 1961-01-30   8.25  16.83  11.80  2.81
# 1961-02-06  10.77  21.83  15.89  3.15
# 1961-02-13   9.54  21.17  13.73  3.11
# 1961-02-20   8.52  16.30  12.60  2.36
# 1961-02-27   7.83  17.84  11.77  2.54
# 1961-03-06   6.88  16.70  10.61  2.75
# 1961-03-13   7.08  19.35  11.76  3.32
# 1961-03-20   6.65  18.13  10.46  3.07
# 1961-03-27   7.30  13.90  10.27  1.88
# 1961-04-03   5.96  13.61   9.41  2.40
# 1961-04-10   4.95   9.48   6.85  1.80
# 1961-04-17   7.77  13.62  10.15  1.90
# 1961-04-24   4.80  10.12   7.45  1.86
# 1961-05-01   9.95  17.55  13.16  2.22
# 1961-05-08   5.30  10.42   8.06  1.49
# 1961-05-15   4.26  12.04   7.47  2.33
# 1961-05-22   3.75  11.70   7.18  2.37
# 1961-05-29   6.31  13.60   9.24  2.17
# 1961-06-05   5.21  12.25   8.46  2.14
# 1961-06-12   6.52  15.35  10.17  2.68
# ...

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Question 5

# %% [markdown]
# ---
# #### Step 1. Import the necessary libraries
# #### Step 2. Import the dataset from this address.
# #### (https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv)
# #### Step 3. Assign it to a variable called chipo.

# %%
# Step 1. Import the necessary libraries
import pandas as pd

# Step 2. Import the dataset from this address. 
# (https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv)
# Step 3. Assign it to a variable called chipo.
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep = '\t')

# %% [markdown]
# ---
# #### Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ---
# #### Step 5. What is the number of observations in the dataset?

# %%
print("Number of observations in the dataset are: {}".format(chipo.shape[0]))
# Out:
# Number of observations in the dataset are: 4622

# %% [markdown]
# ---
# #### Step 6. What is the number of columns in the dataset?

# %%
print("Number of columns in the dataset are: {}".format(chipo.shape[1]))
# Out:
# Number of columns in the dataset are: 5

# %% [markdown]
# ---
# #### Step 7. Print the name of all the columns.

# %%
print("Name of the columns are: {}".format(chipo.columns.tolist()))
# Out:
# Name of the columns are: ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']

# %% [markdown]
# ---
# #### Step 8. How is the dataset indexed?
# ##### Zero-indexed, integer

# %% [markdown]
# ---
# #### Step 9. Which was the most-ordered item?

# %%
# value_counts gives count of each category in a descending order, so we need to select 1st element
print("Most ordered item is: {}".format(chipo.item_name.value_counts().index[0]))
# Out:
# Most ordered item is: Chicken Bowl

# %% [markdown]
# ---
# #### Step 10. For the most-ordered item, how many items were ordered?

# %%
print("Most ordered item was '{}' and it was ordered '{}' times.".format(chipo.item_name.value_counts().index[0], 
                                                              chipo.item_name.value_counts()[0]))
# Out:
# Most ordered item was 'Chicken Bowl' and it was ordered '726' times.

# %% [markdown]
# ---
# #### Step 11. What was the most ordered item in the choice_description column?

# %%
print("Most ordered item in the choice_description column is '{}'".format(chipo.choice_description.value_counts().index[0]))
# Out:
# Most ordered item in the choice_description column is '[Diet Coke]'

# %% [markdown]
# ---
# #### Step 12. How many items were ordered in total?

# %%
print("'{}' items were ordered in total.".format(chipo.quantity.sum()))
# Out:
# '4972' items were ordered in total.

# %% [markdown]
# ---
# #### Step 13.
#
# - Turn the item price into a float
# - Check the item price type
# - Create a lambda function and change the type of item price
# - Check the item price type

# %%
# using str.replace
print(chipo.item_price.str.replace('$', '').astype('float').dtype)

# lambda function
print(chipo.item_price.apply(lambda x : float(x.replace('$', ''))).dtype)

chipo.item_price = chipo.item_price.apply(lambda x : float(x.replace('$', '')))
# Out:
# float64
# float64
# <ipython-input-45-16415d548de3>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   print(chipo.item_price.str.replace('$', '').astype('float').dtype)

# %% [markdown]
# ---
# #### Step 14. How much was the revenue for the period in the dataset?

# %%
print("Total revenue for the peiod is: ${}".format(chipo.item_price.sum()))
# Out:
# Total revenue for the peiod is: $34500.16

# %% [markdown]
# ---
# #### Step 15. How many orders were made in the period?

# %%
print("No. of total orders is: {}".format(len(chipo.order_id.value_counts())))
# Out:
# No. of total orders is: 1834

# %% [markdown]
# ---
# #### Step 16. What is the average revenue amount per order?

# %%
print("Average revenue amount per order: ${}".format(round(chipo.item_price.sum()/len(chipo.order_id.value_counts()), 2)))
# Out:
# Average revenue amount per order: $18.81

# %% [markdown]
# ---
# #### Step 17. How many different items are sold?

# %%
print("No. of items sold is: {}".format(len(chipo.item_name.value_counts())))
# Out:
# No. of items sold is: 50

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Question 6
#
# Create a line plot showing the number of marriages and divorces per capita in the U.S. between 1867 and 2014. Label both lines and show the legend.
# Don't forget to label your axes!

# %%
import matplotlib.pyplot as plt
# change the plot size
plt.rcParams["figure.figsize"] = (15,7)

# increase pixel density
plt.rcParams['figure.dpi'] = 300

marriages = pd.read_csv('input/us-marriages-divorces-1867-2014.csv')

# create a matplotlib subplot
fig, ax = plt.subplots()
ax.plot(marriages['Year'], marriages['Divorces_per_1000'], label = 'Divorces', linewidth = 2)
ax.plot(marriages['Year'], marriages['Marriages_per_1000'], label = 'Marriages', linewidth = 2)

plt.xticks(np.arange(min(marriages['Year']) + 3, max(marriages['Year']), 10))

plt.xlabel('Year', size = 16)
plt.ylabel('# Per 1000', size = 16)

ax.legend()

ax.set_title('US Marriages Divorces (1867-2014)', size = 20)
# Out:
# Text(0.5, 1.0, 'US Marriages Divorces (1867-2014)')

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Question 7
#
# Create a vertical bar chart comparing the number of marriages and divorces per capita in the U.S. between 1900, 1950, and 2000.
# Don't forget to label your axes!

# %%
plt.rcParams["figure.figsize"] = (8,4)
plt.rcParams['figure.dpi'] = 300

# perCapita
marriages["Divorces_perCapita"] = marriages.Divorces_per_1000/1000
marriages["Marriages_perCapita"] = marriages.Marriages_per_1000/1000

marriages.loc[marriages.Year.isin([1900, 1950, 2000]), ['Year', 'Divorces_perCapita', 'Marriages_perCapita']].plot.bar(x = 'Year')
plt.xlabel('Year')
plt.ylabel('# per capita')

plt.title('US Marriages Divorces per Capita in 1900, 1950, and 2000')
# Out:
# Text(0.5, 1.0, 'US Marriages Divorces per Capita in 1900, 1950, and 2000')

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Question 8
#
# Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort the actors by their kill count and label each bar with the corresponding actor's name.
# Don't forget to label your axes

# %%
hollywood = pd.read_csv('input/actor_kill_counts.csv')
# hollywood.head()
hollywood.sort_values('Count', ascending = True).plot.barh(x = 'Actor', y = 'Count', legend = None)
plt.xlabel('No. of kills')
# Out:
# Text(0.5, 0, 'No. of kills')

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Question 9
#
# Create a pie chart showing the fraction of all Roman Emperors that were assassinated.
# Make sure that the pie chart is an even circle, labels the categories, and shows the percentage breakdown of the categories.

# %%
roman = pd.read_csv('input/roman-emperor-reigns.csv')
fig1, ax1 = plt.subplots()
plt.rcParams["figure.figsize"] = (5,5)
plt.rcParams['figure.dpi'] = 200

ax1.pie(roman.Cause_of_Death.value_counts(), labels = roman.Cause_of_Death.value_counts().index.tolist(), startangle=60, autopct='%1.f%%')
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Question 10
#
# Create a scatter plot showing the relationship between the total revenue earned by arcades and the number of Computer Science PhDs awarded in the U.S. between 2000 and 2009.
# Don't forget to label your axes!
# Color each dot according to its year.

# %%
import matplotlib.pyplot as plt
import numpy as np

import pandas as pd
arcade = pd.read_csv('input/arcade-revenue-vs-cs-doctorates.csv')

plt.rcParams['figure.dpi'] = 300

fig, ax = plt.subplots()
ax.scatter(arcade['Total Arcade Revenue (billions)'], arcade['Computer Science Doctorates Awarded (US)'], 
           label = 'Year', linewidth = 2, c = arcade.Year)

plt.xlabel('Revenue earned by Arcades (billions)', size = 16)
plt.ylabel('# Computer Science Phds', size = 16)
ax.legend()
ax.set_title('# Computer Science PhDs (2000-2009) vs Revenue earned by Arcades', size = 20)
# Out:
# Text(0.5, 1.0, '# Computer Science PhDs (2000-2009) vs Revenue earned by Arcades')

# %% [markdown]
# ---
# ---
# ---
